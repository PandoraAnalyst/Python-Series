# %% [markdown]
# # Python Series, ATA-5.

# %% [markdown]
# ## Project - Building a BMI Calculator

# %% [markdown]
# ### Project Guidelines
#
# #### BMI = (weight in pounds * 703) / (height in inches * height in inches)
#
# ![image.png](attachment:5e3f3f3c-1c18-4eaa-be44-0bb05bf1aa81.png)

# %%
## Building out the logic for the calculator

name = input('Enter your name: ')
weight = int(input('Enter your weight in pounds: '))
height = int(input('Enter your height in inches: '))

BMI = (weight * 703) / (height * height)

print(BMI)

## Calculator logic

if BMI > 0:
    if BMI < 18.5:
        print(name + ', you are underweight. Your health risk is Minimal.')
    elif BMI <= 24.9:
        print(name + ', you are normal weight. Your health risk is Minimal.')
    elif BMI <= 29.9:
        print(name + ', you are overweight. Your health risk is Increased.')
    elif BMI <= 34.9:
        print(name + ', you are obese. Your health risk is High.')
    elif BMI <= 39.9:
        print(name + ', you are severely obese. Your health risk is very High.')
    else:
        print(name + ', you are morbidly obese. Your health risk is extremely High.')
else:
    print('Please, enter a valid details')
# Out:
# Enter your name:  Pandora
# Enter your weight in pounds:  280
# Enter your height in inches:  65
# 46.589349112426035
# Pandora, you are morbidly obese. Your health risk is extremely High.
